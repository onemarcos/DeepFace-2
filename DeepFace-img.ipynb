# %%
pip install deepface
# Out:
# ...
#      ---------------------------------------- 65.0/65.0 kB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 87.7/87.7 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 2.3/2.3 MB 16.0 MB/s eta 0:00:00
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      -------------------------------------- 444.0/444.0 MB 1.3 MB/s eta 0:00:00
# ...
#      --------------------------------------- 35.4/35.4 MB 22.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.6/1.6 MB 34.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
# ...

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
img1_path = 'dataset/img1.jpeg'
img2_path = 'dataset/img2.jpg'

# %%
img1 = DeepFace.detectFace(img1_path)
img2 = DeepFace.detectFace(img2_path)

# %%
plt.imshow(img1)

# %%
model_name = 'Facenet'

# %%
resp = DeepFace.verify(img1_path = img1_path, img2_path = img2_path, model_name = model_name)
# Out:
# facenet_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facenet_weights.h5
# To: C:\Users\OneMa\.deepface\weights\facenet_weights.h5
# 100%|█████████████████████████████████████████████████████████████████████████████| 92.2M/92.2M [00:04<00:00, 18.7MB/s]
# ...
# 1/1 [==============================] - 0s 77ms/step

# %%
resp
# Out:
# {'verified': True,
#  'distance': 0.35852403193309546,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine'}

# %%
obj = DeepFace.analyze(img_path = "dataset/img.jpg", actions = ['age', 'gender', 'race', 'emotion'])
# Out:
# ...
# Action: emotion: 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:28<00:00,  7.08s/it]

# %%
obj
# Out:
# {'age': 34,
#  'region': {'x': 98, 'y': 153, 'w': 353, 'h': 353},
#  'gender': 'Man',
#  'race': {'asian': 18.252328723946658,
#   'indian': 14.318271198066617,
#   'black': 3.9556169009944084,
#   'white': 16.915405322957675,
#   'middle eastern': 19.43993353127641,
#   'latino hispanic': 27.118450655752497},
#  'dominant_race': 'latino hispanic',
#  'emotion': {'angry': 23.24077060928695,
#   'disgust': 0.0015229277781934891,
#   'fear': 2.681947366065101,
#   'happy': 0.3165715229500505,
#   'sad': 31.791066313854895,
#   'surprise': 0.005699409351079355,
#   'neutral': 41.96241891832126},
#  'dominant_emotion': 'neutral'}
